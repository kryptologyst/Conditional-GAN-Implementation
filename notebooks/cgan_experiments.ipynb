# %% [markdown]
# # Conditional GAN - Interactive Notebook
#
# This notebook provides an interactive environment for experimenting with the Conditional GAN implementation.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Add src to path
sys.path.append(os.path.join(os.getcwd(), 'src'))

from models.cgan import Generator, Discriminator
from data.mnist import load_mnist_data, create_one_hot_labels
from utils.training import set_seed, get_device, initialize_optimizers
from evaluation.metrics import evaluate_model
